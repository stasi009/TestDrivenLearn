# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.plot(randn(30).cumsum(), 'ro--')

# %%
plt.plot(randn(30).cumsum(),color="b",linestyle="--",marker="*")

# %%
plt.plot?
